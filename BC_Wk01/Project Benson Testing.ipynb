# %%
#going to the MTA website and appending multiple data file into the pandas dataframe.

import pandas as pd

links = ['http://web.mta.info/developers/data/nyct/turnstile/turnstile_180505.txt']#, 
         #'http://web.mta.info/developers/data/nyct/turnstile/turnstile_180512.txt',
        #'#http://web.mta.info/developers/data/nyct/turnstile/turnstile_180519.txt',
        #'http://web.mta.info/developers/data/nyct/turnstile/turnstile_180526.txt',
        #'http://web.mta.info/developers/data/nyct/turnstile/turnstile_180602.txt']

df = pd.concat([pd.read_csv(l) for l in links], ignore_index=True)

# %%
#df.head()
df.loc[(df.STATION == '59 ST')&(df.DATE=='05/05/2018')&(df.TIME=='20:00:00')]
#df.groupby(['STATION']).count()
# Out:
#           C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 197207   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/05/2018  20:00:00
# 197249   A002  R051  02-00-01   59 ST  NQR456W      BMT  05/05/2018  20:00:00
# 197291   A002  R051  02-03-00   59 ST  NQR456W      BMT  05/05/2018  20:00:00
# 197333   A002  R051  02-03-01   59 ST  NQR456W      BMT  05/05/2018  20:00:00
# 197375   A002  R051  02-03-02   59 ST  NQR456W      BMT  05/05/2018  20:00:00
# 197417   A002  R051  02-03-03   59 ST  NQR456W      BMT  05/05/2018  20:00:00
# 197459   A002  R051  02-03-04   59 ST  NQR456W      BMT  05/05/2018  20:00:00
# 197501   A002  R051  02-03-05   59 ST  NQR456W      BMT  05/05/2018  20:00:00
# 197543   A002  R051  02-03-06   59 ST  NQR456W      BMT  05/05/2018  20:00:00
# 197585   A002  R051  02-05-00   59 ST  NQR456W      BMT  05/05/2018  20:00:00
# 197627   A002  R051  02-05-01   59 ST  NQR456W      BMT  05/05/2018  20:00:00
# ...

# %%
#creating two filters before create a filtered dataframe
filter_1 = df[df['TIME'] == '16:00:00']
filter_2 = df[df['TIME'] == '20:00:00']

# %%
#creating a filtered dataframe based in time 
filtered_df = pd.concat([filter_1, filter_2])
#filtered_df.count()
filtered_df.loc[(df.STATION == '59 ST')&(df.DATE=='05/05/2018')]
# Out:
#           C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 197206   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/05/2018  16:00:00
# 197248   A002  R051  02-00-01   59 ST  NQR456W      BMT  05/05/2018  16:00:00
# 197290   A002  R051  02-03-00   59 ST  NQR456W      BMT  05/05/2018  16:00:00
# 197332   A002  R051  02-03-01   59 ST  NQR456W      BMT  05/05/2018  16:00:00
# 197374   A002  R051  02-03-02   59 ST  NQR456W      BMT  05/05/2018  16:00:00
# 197416   A002  R051  02-03-03   59 ST  NQR456W      BMT  05/05/2018  16:00:00
# 197458   A002  R051  02-03-04   59 ST  NQR456W      BMT  05/05/2018  16:00:00
# 197500   A002  R051  02-03-05   59 ST  NQR456W      BMT  05/05/2018  16:00:00
# 197542   A002  R051  02-03-06   59 ST  NQR456W      BMT  05/05/2018  16:00:00
# 197584   A002  R051  02-05-00   59 ST  NQR456W      BMT  05/05/2018  16:00:00
# 197626   A002  R051  02-05-01   59 ST  NQR456W      BMT  05/05/2018  16:00:00
# ...

# %%
import pandas as pd

files = ['http://web.mta.info/developers/data/nyct/turnstile/turnstile_180505.txt']

df1 = pd.concat([pd.read_csv(f) for f in files], ignore_index=True)
df1.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/28/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/28/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/28/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/28/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/28/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6598847
# 1  REGULAR  6598864
# 2  REGULAR  6598880
# 3  REGULAR  6598961
# 4  REGULAR  6599175
#
#    EXITS
# 0                                            2235829
# 1                                            2235830
# 2                                            2235863
# 3                                            2235955
# 4                                            2236015

# %%
 df1_subset = df1[:1001]

# %%
df1_subset.head(10)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/28/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/28/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/28/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/28/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/28/2018  16:00:00
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/28/2018  20:00:00
# 6  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2018  00:00:00
# 7  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2018  04:00:00
# 8  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2018  08:00:00
# 9  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2018  12:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6598847
# 1  REGULAR  6598864
# 2  REGULAR  6598880
# 3  REGULAR  6598961
# 4  REGULAR  6599175
# 5  REGULAR  6599456
# 6  REGULAR  6599584
# ...

# %%
filter_1 = df1_subset[df1_subset['TIME'] == '16:00:00']
filter_2 = df1_subset[df1_subset['TIME'] == '20:00:00']

# %%
temp = pd.concat([filter_1, filter_2])

# %%
temp
# Out:
#       C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 4    A002  R051  02-00-00   59 ST  NQR456W      BMT  04/28/2018  16:00:00
# 10   A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2018  16:00:00
# 16   A002  R051  02-00-00   59 ST  NQR456W      BMT  04/30/2018  16:00:00
# 22   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/01/2018  16:00:00
# 28   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/02/2018  16:00:00
# 34   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/03/2018  16:00:00
# 40   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/04/2018  16:00:00
# 46   A002  R051  02-00-01   59 ST  NQR456W      BMT  04/28/2018  16:00:00
# 52   A002  R051  02-00-01   59 ST  NQR456W      BMT  04/29/2018  16:00:00
# 58   A002  R051  02-00-01   59 ST  NQR456W      BMT  04/30/2018  16:00:00
# 64   A002  R051  02-00-01   59 ST  NQR456W      BMT  05/01/2018  16:00:00
# 70   A002  R051  02-00-01   59 ST  NQR456W      BMT  05/02/2018  16:00:00
# ...
